# %% [markdown]
# # GitHub Rendering Test
#
# This is a simple test notebook to verify GitHub rendering works correctly.

# %%
# Simple Python code
print("Hello, GitHub!")

# Basic data analysis
import pandas as pd
import numpy as np

# Create sample data
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 4, 6, 8, 10]}
df = pd.DataFrame(data)
print(df.head())

# %% [markdown]
# ## Results
#
# If you can see this notebook on GitHub, then rendering is working properly!
